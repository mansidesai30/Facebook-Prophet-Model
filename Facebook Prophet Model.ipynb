# %% [markdown]
#                                                ### Facebook Prophet Model

# %%
#import libraries
from fbprophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the csv file
df = pd.read_csv(r'C:\Users\NQE00254\Desktop\Power BI Reports\Data Science Courses\Python\AirPassengers.csv', encoding = 'unicode_escape')

# %%
#print the dataframe
print (df)
# Out:
#         Date  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]

# %%
#create a Prophet Model
model = Prophet()

# %%
#Change the column names to ds and y
df.columns = ['ds','y']

# %%
model = Prophet()

# %%
#Now fit the model
model.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
#Lets create the future dataframe
future = model.make_future_dataframe(periods = 30,freq = 'D')

# %%
future.tail()
# Out:
#             ds
# 169 1960-12-27
# 170 1960-12-28
# 171 1960-12-29
# 172 1960-12-30
# 173 1960-12-31

# %%
#Predict the future analysis
forecast=model.predict(future)

# %%
#To get the information of the dataframe
forecast
# Out:
#             ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   1949-01-01  106.583811   55.921929  113.836325   106.583811   106.583811
# 1   1949-02-01  108.760063   50.781567  105.810191   108.760063   108.760063
# 2   1949-03-01  110.725710   81.859809  140.719116   110.725710   110.725710
# 3   1949-04-01  112.901962   81.069826  136.885063   112.901962   112.901962
# 4   1949-05-01  115.008012   81.670982  138.194925   115.008012   115.008012
# ..         ...         ...         ...         ...          ...          ...
# 169 1960-12-27  487.024779  414.703163  471.352998   487.024779   487.024779
# 170 1960-12-28  487.125238  421.048209  480.021559   487.125238   487.125238
# 171 1960-12-29  487.225698  425.677076  482.671634   487.225698   487.225698
# 172 1960-12-30  487.326157  430.316682  486.601043   487.326157   487.326157
# 173 1960-12-31  487.426617  430.972133  490.153627   487.426617   487.426617
#
#      additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0        -21.946575            -21.946575            -21.946575 -21.946575
# 1        -30.707281            -30.707281            -30.707281 -30.707281
# 2         -0.469476             -0.469476             -0.469476  -0.469476
# 3         -5.166670             -5.166670             -5.166670  -5.166670
# 4         -3.765920             -3.765920             -3.765920  -3.765920
# ..              ...                   ...                   ...        ...
# 169      -43.165360            -43.165360            -43.165360 -43.165360
# 170      -38.269699            -38.269699            -38.269699 -38.269699
# 171      -33.604061            -33.604061            -33.604061 -33.604061
# 172      -29.269023            -29.269023            -29.269023 -29.269023
# 173      -25.356311            -25.356311            -25.356311 -25.356311
#
#      yearly_lower  yearly_upper  multiplicative_terms  \
# 0      -21.946575    -21.946575                   0.0
# 1      -30.707281    -30.707281                   0.0
# 2       -0.469476     -0.469476                   0.0
# 3       -5.166670     -5.166670                   0.0
# 4       -3.765920     -3.765920                   0.0
# ..            ...           ...                   ...
# 169    -43.165360    -43.165360                   0.0
# 170    -38.269699    -38.269699                   0.0
# 171    -33.604061    -33.604061                   0.0
# 172    -29.269023    -29.269023                   0.0
# 173    -25.356311    -25.356311                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                           0.0                         0.0   84.637236
# 1                           0.0                         0.0   78.052782
# 2                           0.0                         0.0  110.256234
# 3                           0.0                         0.0  107.735292
# 4                           0.0                         0.0  111.242092
# ..                          ...                         ...         ...
# 169                         0.0                         0.0  443.859419
# 170                         0.0                         0.0  448.855539
# 171                         0.0                         0.0  453.621637
# 172                         0.0                         0.0  458.057134
# 173                         0.0                         0.0  462.070306
#
# [174 rows x 16 columns]

# %%
#To get the information of the dataframe
forecast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ds                          174 non-null    datetime64[ns]
#  1   trend                       174 non-null    float64
#  2   yhat_lower                  174 non-null    float64
#  3   yhat_upper                  174 non-null    float64
#  4   trend_lower                 174 non-null    float64
#  5   trend_upper                 174 non-null    float64
#  6   additive_terms              174 non-null    float64
#  7   additive_terms_lower        174 non-null    float64
#  8   additive_terms_upper        174 non-null    float64
#  9   yearly                      174 non-null    float64
#  10  yearly_lower                174 non-null    float64
#  11  yearly_upper                174 non-null    float64
#  12  multiplicative_terms        174 non-null    float64
#  13  multiplicative_terms_lower  174 non-null    float64
#  14  multiplicative_terms_upper  174 non-null    float64
#  15  yhat                        174 non-null    float64
# dtypes: datetime64[ns](1), float64(15)
# memory usage: 21.9 KB

# %%
#import
import matplotlib as plt

# %%
#Select the columns
forecast[['ds','yhat_lower','yhat_upper','yhat']].tail()
# Out:
#             ds  yhat_lower  yhat_upper        yhat
# 169 1960-12-27  414.703163  471.352998  443.859419
# 170 1960-12-28  421.048209  480.021559  448.855539
# 171 1960-12-29  425.677076  482.671634  453.621637
# 172 1960-12-30  430.316682  486.601043  458.057134
# 173 1960-12-31  430.972133  490.153627  462.070306

# %%
#plot the model
model.plot(forecast)

# %%
#Plotting the Components
fig1 = model.plot_components(forecast)
